# %% [markdown]
# **SHAKESPEARE AND DATA SCIENCE**

# %% [markdown]
# **Import Libraries and Dataset**

# %%
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import regex as re
lemmatizer = WordNetLemmatizer()

# %%
'''https://www.kaggle.com/kingburrito666/shakespeare-plays
The first column is the Data-Line, it just keeps track of all the
rows there are.
The second column is the play that the lines are from.
The third column is the actual line being spoken at any given time.
The fourth column is the Act-Scene-Line from which any given line is
from.
The fifth column is the player who is saying any given line.
The sixth column is the line being spoken.'''

df = pd.read_csv(r'./Shakespeare_data.csv')

# %% [markdown]
# **Basic Data Exploration**

# %%
df.head(10)
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               NaN          NaN            NaN
# 1         2  Henry IV               NaN          NaN            NaN
# 2         3  Henry IV               NaN          NaN            NaN
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
# 5         6  Henry IV               1.0        1.1.3  KING HENRY IV
# 6         7  Henry IV               1.0        1.1.4  KING HENRY IV
# 7         8  Henry IV               1.0        1.1.5  KING HENRY IV
# 8         9  Henry IV               1.0        1.1.6  KING HENRY IV
# 9        10  Henry IV               1.0        1.1.7  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# ...

# %%
df.isnull().sum() # Use fillna to fill nulls with 0
# Out:
# Dataline               0
# Play                   0
# PlayerLinenumber       3
# ActSceneLine        6243
# Player                 7
# PlayerLine             0
# dtype: int64

# %%
df.fillna(0,inplace=True)
df.isnull().sum()
# Out:
# Dataline            0
# Play                0
# PlayerLinenumber    0
# ActSceneLine        0
# Player              0
# PlayerLine          0
# dtype: int64

# %%
df.shape
# Out:
# (111396, 6)

# %%
df.dtypes
# Out:
# Dataline              int64
# Play                 object
# PlayerLinenumber    float64
# ActSceneLine         object
# Player               object
# PlayerLine           object
# dtype: object

# %%
# Check frequency of unique values among characters
# Make chart of characters with most and least lines overall, specific plays
# Look at male and female character line counts
df['Player'].value_counts(normalize=True)
# Out:
# GLOUCESTER       0.017236
# HAMLET           0.014202
# IAGO             0.010422
# FALSTAFF         0.010027
# KING HENRY V     0.009749
#                    ...
# HORTENSIA        0.000009
# A Lord           0.000009
# Second Knight    0.000009
# First Roman      0.000009
# PHILIP           0.000009
# Name: Player, Length: 935, dtype: float64

# %%
# List of all female characters in Shakespeare's plays
# http://www.shakespeare-online.com/plays/characters/charactermain.html
# https://www.britannica.com/topic/list-of-characters-in-plays-by-Shakespeare-2069474
# https://www.playshakespeare.com/study/complete-shakespeare-character-list

# %%
# List of all male characters in Shakespeare's plays
# http://www.shakespeare-online.com/plays/characters/charactermain.html
# https://www.britannica.com/topic/list-of-characters-in-plays-by-Shakespeare-2069474
# https://www.playshakespeare.com/study/complete-shakespeare-character-list

# %% [markdown]
# **Pre-Processing**

# %%
# https://www.kdnuggets.com/2019/04/text-preprocessing-nlp-machine-learning.html
# Text pre-processing
# 1. Lowercase the text
# 2. Lemmatize the text
# 3. Stopword removal
# 4. Normalization (thinking no here) (e.g. standardize near identical words)
# 5. Noise removal
# 6. Remove punctuation
'''lower_words=[word.lower() for word in texts]
lower_words'''

'''from nltk.stem import WordNetLemmatizer
nltk.download('wordnet)
# init lemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(word=word,pos='v') for word in words]
lemmatizeddf= pd.DataFrame({'original_word': words,'lemmatized_word': lemmatized_words})
lemmatizeddf=lemmatizeddf[['original_word','lemmatized_word']]
lemmatizeddf'''

# %%
# Stop Word Removal
'''stopwords=[]
text = 
words=text.split(" ")
shortlisted_words=[]
#remove stop words
for w in words:
    if w not in stopwords:
        shortlisted_words.append(w)
    else:
        shortlisted_words.append("W")
shortlisted_words=[]
'''
#remove stop words
for w in words:
    if w not in stopwords:
        shortlisted_words.append(w)
    else:
        shortlisted_words.append("W")

# %%
'''def scrub_words(text):
    #remove punctuation
    
    #remove whitespace
    text=text.strip()
    return text'''

# %%
# https://towardsdatascience.com/nlp-text-preprocessing-a-practical-guide-and-template-d80874676e79
'''List of Text Preprocessing Steps
Remove HTML tags
Remove extra whitespaces
Convert accented characters to ASCII characters
Expand contractions
Remove special characters
Lowercase all texts
Convert number words to numeric form
Remove numbers
Remove stopwords
Lemmatization'''

from pycontractions import Contractions
def expand_contractions(text):
    """expand shortened words, e.g. don't to do not"""
    text = list(cont.expand_texts([text], precise=True))[0]
    return text

# Lemmatize text
text = 
doc = nlp(text)
# Lemmatizing each token
mytokens = [word.lemma_ if word.lemma_ != "-PRON-" else word.lower_ for word in doc]

# %%
# https://towardsdatascience.com/nlp-for-beginnerscleaning-preprocessing-text-data-ae8e306bef0f
# Remove punctuation list comprehension
# stop words
from nltk.corpus import stopwords
stopwords.word(english)
def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

# %%
# https://medium.com/@datamonsters/text-preprocessing-in-python-steps-tools-and-examples-bf025f872908
# Lowercase text
input_str = ""
input_str = input_str.lower()
print(input_str)

# Remove punctuation
import string
input_str = “This &is [an] example? {of} string. with.? punctuation!!!!” #Sample string
result = input_str.translate(string.maketrans(“”,””), string.punctuation)
print(result)

# white spaces removal
input_str = “ \t a string example\t “
input_str = input_str.strip()
input_str

# Stop words removal
input_str = “NLTK is a leading platform for building Python programs to work with human language data.”
stop_words = set(stopwords.words(‘english’))
from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
result = [i for i in tokens if not i in stop_words]
print (result)

# Also: from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

# Lemmatizing using NLTK
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
lemmatizer=WordNetLemmatizer()
input_str="been had done languages cities mice"
input_str=word_tokenize(input_str)
for word in input_str:
    print(lemmatizer.lemmatize(word))

'''Chunking is a natural language process that identifies constituent 
parts of sentences (nouns, verbs, adjectives, etc.) and links them to 
higher order units that have discrete grammatical meanings (noun groups 
or phrases, verb groups, etc.)'''
# Chunking using NLTK
# Step one (determine part of speech for each word)
input_str=”A black television and a white stove were bought for the new apartment of John.”
from textblob import TextBlob
result = TextBlob(input_str)
print(result.tags)
# Step Two (the chunking step)
reg_exp = “NP: {<DT>?<JJ>*<NN>}”
rp = nltk.RegexpParser(reg_exp)
result = rp.parse(result.tags)
print(result)

'''Named-entity recognition (NER) aims to find named entities in text and 
classify them into pre-defined categories (names of persons, locations, 
organizations, times, etc.).'''
# Named-entity recognition using NLTK
from nltk import word_tokenize, pos_tag, ne_chunk
input_str = “Bill works for Apple so he went to Boston for a conference.”
print ne_chunk(pos_tag(word_tokenize(input_str)))

# Relationship extraction
# Relationship extraction allows obtaining structured information from 
#unstructured sources such as raw text. Strictly stated, it is identifying 
#relations (e.g., acquisition, spouse, employment) among named entities 
#(e.g., people, organizations, locations). 
# Possible options: TETRE, TextRazor, IEPY
# Out:
#   File "<ipython-input-1-bdba8b7e05da>", line 9
#     input_str = “This &is [an] example? {of} string. with.? punctuation!!!!” # Sample string
#                     ^
# SyntaxError: invalid character in identifier

# %%
# https://medium.com/shortcutnlp/the-comprehensive-nlp-preprocessing-list-and-simplest-code-kit-shortcutnlp-7a6f7a8963b9
'''The output of NLP is classified in the following 3 types:
1. Continuous Value in the Regression problem
2. Class in the Classification problem
3. Text in a Communication application
NLP can be brokedown like this:
1. Cleaning Text Data: from Unstructured to Bag of words
2. Vectorization with Semantic Embedding: acquire Numerical features
3. Converting into Output: value and class, text, voice…'''

# NLP preprocessing task list
'''1. Data Preparation: from text to sentence
2. Non-alphanumeric data removing: number, symbol, emoji, HTML tag…
3. Lowercase and Miss-spelling normalization
4. Tokenization: from sentence to word
5. Stop Words removing
6. Stemming and Lemmatization
7. Bag of words: Tf-Idf
8. Word Embedding: Word2Vec'''
    
#Lowercase and Miss-spelling normalization
text_df["text"].apply(lambda x: " ".join(x.lower() for x in x.split()))
print(text_df["text"].head())

# Non-alphanumeric data removing: number, symbol, emoji, HTML tag…
text_df["text"].str.replace(r"\d+", "")
text_df["text"].str.replace('[^\w\s]','')
text_df["text"].str.replace(r"[︰-＠]", "")
print(text_df["text"].head())

#Tokenization: from sentence to word
# nltk.download('punkt')
from nltk.tokenize import word_tokenize
text_df["text"].apply(word_tokenize)
print(text_df["text"].head())

# Stop Words removing
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words("english")
text_df["text"].apply(lambda x: [item for item in x if item not in stop_words])
print(text_df["text"].head())

# Bag of words, Tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=0.03)
tfidf = vectorizer.fit_transform(text_df["text"])
tfidf.toarray()

# Word Embedding: Word2Vec
from gensim.models import Word2Vec
model = Word2Vec(text_df["text"], size=150, window=10)
model.train(text_df["text"], total_examples=len(text_df["text"]), epochs=10)
model.wv.most_similar(positive=["home"])

# %%
# How might I use Regex tokenize patterns in Shakespeare? (try different
# approaches)

# %% [markdown]
# **Simple Sentiment Analysis**

# %%
# Upload large text files: a) positive words, b) negative words
# Pick one or a few famous monologues
# Male vs. female
# Comedy vs tragedy vs history play
# A single play as it progresses from character to character 
# (create function?)

# %% [markdown]
# **Simple Classification -w- Linear Regression**

# %%
# Pick texts to run classification model on (comedy vs. tragedy?)
# Create comedy dataframe and trajedy dataframe 
# Train/Test/Split
# Remove punctuation (regex)
# Remove stopwords (nltk)
# CountVectorize the texts
# Fit Logistic Regression
# Evaluate model

# %%
# Simple model -w- TFIDF Vectorization
# TFIDF, pipeline, GridSearch, Logistic Regression (Tragedy & Comedy texts)

# %% [markdown]
# **Word Vector - Word2Vec**

# %%
# This section indebted to Matt Brems' "Word Vectors" GA lecture and notebook.
import gensim # Review Gensim documentation: https://radimrehurek.com/gensim/auto_examples/index.html

# %%
# Need to define what text to make into vector file
# !!! What analysis do I want to do with Word2Vec???
# Import word vectors into "model."

model = gensim.models.KeyedVectors.load_word2vec_format('shakey_vector_file_name')

# %%
# Note: Research Continuous Bag-of-Words (CBOW) and Continuous Skip-grams

# %%
# Idea: Create file of all character names. Investigate possible analyses.

# %%
# Idea: Investigate analysis around key words related to key themes:
# love, death, loyalty, family, truth, friendship, royalty, fate, etc.

# %%
# Create word vectors from Shakespeare corpus - cleaned text.
# # Import Word2Vec
# from gensim.models.word2vec import Word2Vec

# # If you want to use gensim's data, import their downloader
# # and load it.
# import gensim.downloader as api
# corpus = api.load('text8')

# # If you have your own iterable corpus of cleaned data, you can 
# # read it in as corpus and pass that in.

# # Train a model! 
# model = Word2Vec(corpus,      # Corpus of data.
#                  size=100,    # How many dimensions do you want in your word vector?
#                  window=5,    # How many "context words" do you want?
#                  min_count=1, # Ignores words below this threshold.
#                  sg=0,        # SG = 1 uses SkipGram, SG = 0 uses CBOW (default).
#                  workers=4)   # Number of "worker threads" to use (parallelizes process).

# # Do what you'd like to do with your data!
# model.most_similar("car")

# %%
# Doc2Vec paragraph embeddings: https://radimrehurek.com/gensim/models/doc2vec.html#gensim.models.doc2vec.Doc2Vec
# Word2Vec Tutorial: https://rare-technologies.com/word2vec-tutorial/
# FastText word representations: https://radimrehurek.com/gensim/models/fasttext.html#gensim.models.fasttext.FastText

# %% [markdown]
# **Background Reading**

# %%
# Scholarly articles on Shakespeare and data science/machine learning
(Henry VIII) https://ui.adsabs.harvard.edu/abs/2019arXiv191105652P/abstract
Google Tutorial on training TensorFlow model to generate Shakespeare text: https://opensource.google/projects/tensorflow-deeplearning-nophd
"Character-to-Character Sentiment Analysis in Shakespeare’s Plays," https://www.aclweb.org/anthology/P13-2085/
https://science.sciencemag.org/content/357/6346/23.summary  
http://www.shakespeareassociation.org/wp-content/uploads/2019/02/2019-Seminar-Abstracts-Shakespeare-at-Scale.pdf

# %%
#General articles on Shakespeare and data science/machine learning
There are a lot of articles about this discovery on Henry VIII and 
John Fletcher - https://www.technologyreview.com/s/614742/machine-learning-has-revealed-exactly-how-much-of-a-shakespeare-play-was-written-by-someone/
https://towardsdatascience.com/can-ai-write-like-shakespeare-de710befbfee
https://interestingengineering.com/shakespeares-art-is-still-being-questioned-this-time-by-machine-learning
Generating text from Shakespeare: http://karpathy.github.io/2015/05/21/rnn-effectiveness/
https://github.com/topics/shakespeare (45 separate topics)
https://techcrunch.com/2014/01/26/swift-speare/

# %%
# Project Outline
# clean and prepare corpus
# create separate tragedy and comedy and history play dataframes
# create a simple sentiment analysis (what?)
# create a boolean classification model -w- logistic regression (tragedy vs. comedy)
# create a three-part classification model -w- a different algo (RF? SVM?) (tragedy, comedy, history)
# Investigate an analysis with Word2Vector or associated vector model
# Research literature to see if there is a relevant unsupervised model (analytical, generative)
# Revise project so each part feeds into the next: sentiment/classification/Vector/UnsupervisedML
# Possible addition: Put corpus on a database server. Use SQL to pull text to jupyter notebook.
# Possible addition: Use Open ML on Google Cloud to explore/compare a different tool set.

# %%
# First df content groups: a) histories, b) comedies, c) tragedies

# %%
# Pandas help: https://thispointer.com/python-pandas-select-rows-in-dataframe-by-conditions-on-multiple-columns/
# List of History Plays http://shakespeare.mit.edu/works.html
# Select by Play, PlayerLine
'''Henry IV, part 1 
Henry IV, part 2
Henry V
Henry VI, part 1
Henry VI, part 2
Henry VI, part 3
Henry VIII
King John
Richard II
Richard III'''

#Return rows in 'PlayerLine' column, where rows in "Play" column = spec. plays
df_history = pd.DataFrame()

df_history = df.loc[df['Play'].isin(['Henry IV', 'Henry V', 'Henry VI', 'Henry VIII', 'King John', 'Richard II', 'Richard III'])]

df_history.head()
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               0.0            0              0
# 1         2  Henry IV               0.0            0              0
# 2         3  Henry IV               0.0            0              0
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
df_history.shape
# Out:
# (19663, 6)

# %%
# List of Comedies http://shakespeare.mit.edu/works.html
'''All's Well That Ends Well
As You Like It
The Comedy of Errors
Cymbeline
Love's Labours Lost
Measure for Measure
The Merry Wives of Windsor
The Merchant of Venice
A Midsummer Night's Dream
Much Ado About Nothing
Pericles, Prince of Tyre
Taming of the Shrew
The Tempest
Troilus and Cressida
Twelfth Night
Two Gentlemen of Verona
Winter's Tale'''

df_comedy = df.loc[df['Play'].isin(["All's Well That Ends Well",'As You Like It','The Comedy of Errors','Cymbeline',"Loves Labours Lost",'Measure for Measure','The Merry Wives of Windsor','The Merchant of Venice',"A Midsummer Nights Dream",'Much Ado About Nothing','Pericles, Prince of Tyre','Taming of the Shrew','The Tempest','Troilus and Cressida','Twelfth Night','Two Gentlemen of Verona',"Winter's Tale"])]

df_comedy.head()
# Out:
#        Dataline       Play  PlayerLinenumber ActSceneLine           Player  \
# 28474     28475  Cymbeline              49.0            0         AUFIDIUS
# 28475     28476  Cymbeline              49.0            0         AUFIDIUS
# 28476     28477  Cymbeline              49.0            0         AUFIDIUS
# 28477     28478  Cymbeline               1.0        1.1.1  First Gentleman
# 28478     28479  Cymbeline               1.0        1.1.2  First Gentleman
#
#                                               PlayerLine
# 28474                                              ACT I
# 28475  SCENE I. Britain. The garden of Cymbeline's pa...
# 28476                                Enter two Gentlemen
